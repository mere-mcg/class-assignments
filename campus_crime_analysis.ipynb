# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('campus_crime.csv')

data[:1]
# Out:
#                  instname  total_enr  murder  manslaughter  forcible  \
# 0  American River College      95250       0             0         1
#
#    nonforce  robbery  agg_aslt  burglary  vehicle  arson
# 0         2        3         2         6        8      0

# %%
data[data.instname == 'University of Missouri-Columbia']
# Out:
#                             instname  total_enr  murder  manslaughter  \
# 195  University of Missouri-Columbia      33762       0             0
#
#      forcible  nonforce  robbery  agg_aslt  burglary  vehicle  arson
# 195        11         0        1         8        10        1      1

# %%
data["total_count"] = data["murder"] + data["manslaughter"] + data["forcible"]\
  + data["nonforce"] + data["robbery"] + data["agg_aslt"] + data["burglary"]\
  + data['vehicle'] + data["arson"]

data[:5]
# Out:
#                             instname  total_enr  murder  manslaughter  \
# 0             American River College      95250       0             0
# 1           Arizona State University     289016       0             0
# 2                 Ashford University      74596       0             0
# 3                  Auburn University      25469       0             0
# 4  Austin Community College District    1082400       0             0
#
#    forcible  nonforce  robbery  agg_aslt  burglary  vehicle  arson  \
# 0         1         2        3         2         6        8      0
# 1        17         1       11        27        90       17     11
# 2         2         0        0         0         1        0      0
# 3         1         0        2         0        22        3      0
# 4         0         0        0         1         2        0      0
#
#    total_count
# 0           22
# 1          174
# 2            3
# 3           28
# 4            3

# %%
# Highlight Pinellas with facetgrid
g = sns.FacetGrid(data, size=7)

g.map(plt.scatter, "total_enr", "total_count", alpha=.8)

# %%
smaller_data = data[data.total_enr < 50000]

# Highlight Pinellas with facetgrid
g = sns.FacetGrid(smaller_data, size=7)

g.map(plt.scatter, "total_enr", "total_count", alpha=.8)

# %%
data[data.instname == 'University of Kansas']
# Out:
#                  instname  total_enr  murder  manslaughter  forcible  \
# 186  University of Kansas     111756       0             0         4
#
#      nonforce  robbery  agg_aslt  burglary  vehicle  arson  total_count
# 186         0        1         9        39        7      1           61

# %%
data[data.instname == 'University of Missouri-Columbia']
# Out:
#                             instname  total_enr  murder  manslaughter  \
# 195  University of Missouri-Columbia      33762       0             0
#
#      forcible  nonforce  robbery  agg_aslt  burglary  vehicle  arson  \
# 195        11         0        1         8        10        1      1
#
#      total_count
# 195           32

# %%
Story Idea #1: I was going to compare KU and MU's crime numbers. But, I think KU's total enrollment number seems way too large. It seems like the number of reported robberies is too low for both of campuses. Are robberies going underreported?

# %%
data.sort_values('arson', ascending=False)[:10]
# Out:
#                                       instname  total_enr  murder  \
# 116  Pennsylvania State University-Main Campus      45628       0
# 1                     Arizona State University     289016       0
# 140              St John's University-New York     147469       0
# 43                 Eastern Michigan University     210771       0
# 52                         Fresno City College      40270       0
# 108                Ohio University-Main Campus      26201       0
# 107          Ohio State University-Main Campus      56867       0
# 166          University of California-Berkeley      72274       0
# 15      California State University-Sacramento      28016       0
# 133                  San Jose State University      60472       2
#
#      manslaughter  forcible  nonforce  robbery  agg_aslt  burglary  vehicle  \
# 116             0        24         0        2         6       112        1
# 1               0        17         1       11        27        90       17
# ...

# %%
data.sort_values('arson', ascending=False)[:20]
# Out:
#                                               instname  total_enr  murder  \
# 116          Pennsylvania State University-Main Campus      45628       0
# 1                             Arizona State University     289016       0
# 140                      St John's University-New York     147469       0
# 43                         Eastern Michigan University     210771       0
# 52                                 Fresno City College      40270       0
# 108                        Ohio University-Main Campus      26201       0
# 107                  Ohio State University-Main Campus      56867       0
# 166                  University of California-Berkeley      72274       0
# 15              California State University-Sacramento      28016       0
# 133                          San Jose State University      60472       2
# 193                   University of Michigan-Ann Arbor      42716       0
# 184         University of Illinois at Urbana-Champaign      88814       0
# ...

# %%
data.sort_values('burglary', ascending=False)[:20]
# Out:
#                                       instname  total_enr  murder  \
# 209                       University of Toledo      67830       0
# 169       University of California-Los Angeles      39271       0
# 206      University of South Carolina-Columbia      30721       0
# 116  Pennsylvania State University-Main Campus      45628       0
# 142                     Stony Brook University      23920       0
# 210                         University of Utah      31660       0
# 1                     Arizona State University     289016       0
# 69              Indiana University-Bloomington      42731       0
# 167             University of California-Davis      63464       0
# 91                   Michigan State University     191300       0
# 176              University of Colorado Denver      44990       0
# 182                      University of Houston     119460       0
# 162                      University at Buffalo      28849       0
# ...

# %%
data.sort_values('forcible', ascending=False)[:20]
# Out:
#                                               instname  total_enr  murder  \
# 166                  University of California-Berkeley      72274       0
# 107                  Ohio State University-Main Campus      56867       0
# 167                     University of California-Davis      63464       0
# 213                    University of Wisconsin-Madison      41946       0
# 116          Pennsylvania State University-Main Campus      45628       0
# 65                                  Harvard University      54784       0
# 1                             Arizona State University     289016       0
# 56                        George Washington University     202080       0
# 91                           Michigan State University     191300       0
# 219  Virginia Polytechnic Institute and State Unive...     371232       1
# 193                   University of Michigan-Ann Arbor      42716       0
# 211                 University of Virginia-Main Campus     145782       0
# ...

# %%
smaller_data = data[data.total_enr < 50000]

# Highlight Pinellas with facetgrid
g = sns.FacetGrid(smaller_data, size=7)

g.map(plt.scatter, "total_enr", "total_count", alpha=.8)

# %%
data.sort_values('murder', ascending=False)
# Out:
#                                               instname  total_enr  murder  \
# 133                          San Jose State University      60472       2
# 164                              University of Arizona      39236       1
# 219  Virginia Polytechnic Institute and State Unive...     371232       1
# 183                  University of Illinois at Chicago      84273       1
# 0                               American River College      95250       0
# 155                 The University of Texas at El Paso      22640       0
# 145                    Tarrant County College District     300372       0
# 146                                  Temple University     294840       0
# 147             Texas A & M University-College Station     100460       0
# 148                  Texas State University-San Marcos      68174       0
# 149                              Texas Tech University     226289       0
# 150          The Community College of Baltimore County     157626       0
# ...

# %%
data.sort_values('murder', ascending=False)[:20]
# Out:
#                                               instname  total_enr  murder  \
# 133                          San Jose State University      60472       2
# 164                              University of Arizona      39236       1
# 219  Virginia Polytechnic Institute and State Unive...     371232       1
# 183                  University of Illinois at Chicago      84273       1
# 0                               American River College      95250       0
# 155                 The University of Texas at El Paso      22640       0
# 145                    Tarrant County College District     300372       0
# 146                                  Temple University     294840       0
# 147             Texas A & M University-College Station     100460       0
# 148                  Texas State University-San Marcos      68174       0
# 149                              Texas Tech University     226289       0
# 150          The Community College of Baltimore County     157626       0
# ...

# %%
Story Idea #2: There were five reported murders out of all of the schools. What were the causes behind these murders? Who were the students? When did the murders occur?

# %%
data.sort_values('manslaughter', ascending=False)[:20]
# Out:
#                                       instname  total_enr  murder  \
# 51                    Florida State University      41087       0
# 0                       American River College      95250       0
# 157                Thomas Edison State College      20251       0
# 146                          Temple University     294840       0
# 147     Texas A & M University-College Station     100460       0
# 148          Texas State University-San Marcos      68174       0
# 149                      Texas Tech University     226289       0
# 150  The Community College of Baltimore County     157626       0
# 151                  The University of Alabama      63294       0
# 152                The University of Tennessee      90582       0
# 153       The University of Texas at Arlington     100317       0
# 154          The University of Texas at Austin      51112       0
# 155         The University of Texas at El Paso      22640       0
# ...

# %%
data.sort_values('vehicle', ascending=False)[:20]
# Out:
#                                     instname  total_enr  murder  manslaughter  \
# 198     University of New Mexico-Main Campus      28977       0             0
# 130               San Diego State University      30541       0             0
# 189      University of Maryland-College Park      75262       0             0
# 90                        Miami Dade College     509888       0             0
# 173            University of Central Florida     935440       0             0
# 197           University of Nevada-Las Vegas      54728       0             0
# 112                  Oregon State University      24962       0             0
# 13   California State University-Los Angeles      21284       0             0
# 170       University of California-Riverside      20900       0             0
# 182                    University of Houston     119460       0             0
# 206    University of South Carolina-Columbia      30721       0             0
# ...

# %%
data.sort_values('robbery', ascending=False)[:20]
# Out:
#                                               instname  total_enr  murder  \
# 71                   Instituto de Banca y Comercio Inc      20876       0
# 1                             Arizona State University     289016       0
# 173                      University of Central Florida     935440       0
# 86   Louisiana State University and Agricultural & ...      29718       0
# 204                         University of Pennsylvania     148992       0
# 166                  University of California-Berkeley      72274       0
# 51                            Florida State University      41087       0
# 107                  Ohio State University-Main Campus      56867       0
# 150          The Community College of Baltimore County     157626       0
# 200          University of North Carolina at Charlotte      25277       0
# 183                  University of Illinois at Chicago      84273       1
# 110                            Old Dominion University      24753       0
# ...

# %%
Story #3: I was surprised to see Instituto de Banca y Comercio Inc on this list, but I found out it is in Puerto Rico. It would be interesting to know about the campus safety procedures the university has in comparison to continental U.S. schools.
